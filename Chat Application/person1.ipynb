# %%
import socket
import threading

HOST = '127.0.0.1'
PORT = 5555

client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client.connect((HOST, PORT))

def receive():
    while True:
        try:
            message = client.recv(1024).decode()
            print("\nFriend:", message)
        except:
            print("Connection closed")
            client.close()
            break

# Start receiving thread
threading.Thread(target=receive, daemon=True).start()

# Main thread handles input (IMPORTANT)
while True:
    msg = input("You: ")
    client.send(msg.encode())
# Out:
# You:  hello
# Friend: hii
# You:  how are you
# Friend: fine
#
# Friend: what about you
# You:  hii person 2
# Friend: hii person 1
# You:  how are you
# Friend: fine
